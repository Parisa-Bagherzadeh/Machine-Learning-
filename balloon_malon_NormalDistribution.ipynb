# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
balloon_width=np.random.normal(30,5,50)
balloon_length=np.random.normal(30,5,50)
balloon_weight=np.random.normal(2,1,50)
                                
melon_width=np.random.normal(6,3,50)
melon_length=np.random.normal(15,3,50)
melon_weight=np.random.normal(6,2,50)

# %%
melon_width
# Out:
# array([ 5.37907833,  8.19331536,  6.05400757,  4.48331072,  3.11810099,
#         5.41035459,  5.84328959,  2.75507013,  3.66577089,  4.17832386,
#         6.62519313,  9.64118693,  4.106361  ,  4.96350575,  4.59026106,
#         3.82057128,  6.55002086,  3.21203923,  5.88765009,  5.34327015,
#         5.28457698,  5.77856555,  5.86303992,  6.16575028,  5.63713185,
#         6.01638133,  3.59232103,  2.3757817 ,  7.01927958,  3.6080619 ,
#         6.24357213,  6.20670195,  3.95608656,  4.1597593 ,  2.55778726,
#         3.85078521,  6.33885301,  2.30965272,  6.33121666, -0.41680597,
#         5.77552071,  9.1748567 ,  5.51144702,  3.30209076,  7.26852447,
#         5.51676383,  5.37013697,  5.12647162,  2.04086845,  7.68222696])

# %%
width=np.concatenate((balloon_width,melon_width))
length=np.concatenate((balloon_length,melon_length))
weight=np.concatenate((balloon_weight,melon_weight))
data=np.array([width,length,weight]).T
data.shape
# Out:
# (100, 3)

# %%
fig=plt.figure()
p=plt.axes(projection='3d')
#blue=balloon
#orange=melon

p.scatter(data[0:50,0],data[0:50,1],data[0:50,2],c='blue',marker='^')
p.scatter(data[50:,0],data[50:,1],data[50:,2],c='orange')
p.set_xlabel('Width')
p.set_ylabel('Length')
p.set_zlabel('Weight')
# Out:
# Text(0.5, 0, 'Weight')
